# %%
my_var = 'my fancy text'
print(my_var)
# Out:
# my fancy text

# %%
type(3.14)
# Out:
# float

# %%
a = 1_869 + 67.34
print(a)
type(a)
# Out:
# 1936.34
# float

# %%
type(['dog', 'cat', 'ape'])
# Out:
# list

# %%
t = 'New York'
t[4:]
# Out:
# 'York'

# %%
text_1 = 'Hello'
text_2 = 'World!'
text_3 = text_1 + ' ' + text_2

print(text_3)
# Out:
# Hello World!

# %%
len('edoardo')
# Out:
# 7
